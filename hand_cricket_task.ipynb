# %%
# user vs computer hand cricket
import random
a=["batting","bowling"]
l=[1,2,3,4,5,6]
select=input("enter your decision between even or odd : ") #use only small letters
user_toss_score= int(input("enter number between 1 to 6 for the toss : "))
print("user entered : ",user_toss_score)
comp_toss_score= random.choice(l)
print("computer value between 1 and 6  is : ",comp_toss_score)
sum=user_toss_score+comp_toss_score
print("the total value of user and computer is : ",sum)
if select=="even":
    if sum%2==0:
        print("user won the toss")
        user_inning=input(" do you want to bat or ball (enter batting or bowling) : ","\n")
        if user_inning=="batting":
            comp_inning="bowling"
            print('user won the toss ,user has chosen batting so computer will be bowling')
            print("user will be",user_inning,"and computer will be",comp_inning)
            
        else :
            comp_inning="batting"
            print('user won the toss ,user has chosen bowling so computer will be batting')
            print("user will be",user_inning,"and computer will be",comp_inning)
            
    else :
        print("computer won the toss")
        comp_inning=random.choice(a)
        print("computer has chosen to :",comp_inning )
        print("\n")
        if comp_inning=="batting":
            user_inning="bowling"
            print('user lost the toss ,computer has chosen batting so user will be bowling')
            print("user will be",user_inning,"computer will be",comp_inning)
            
        else :
            user_inning="batting"
            print("user lost the toss , computer has chosen bowling so user will be batting")
            print("user will be",user_inning,"computer will be",comp_inning)
            
else :
    if sum%2==0:
        print("computer won the toss")
        comp_inning=random.choice(a)
        print("computer has chosen to :",comp_inning ,"\n")
        if comp_inning=="batting":
            user_inning="bowling"
            print('user lost the toss ,computer has chosen batting so user will be bowling')
            print("user will be",user_inning,"computer will be",comp_inning)
            
        else :
            user_inning='batting'
            print("user lost the toss , computer has chosen bowling so user will be batting")
            print("user will be",user_inning,"computer will be",comp_inning)
            
    else :
        print("user won the toss")
        user_inning=input("do you want to bat or ball (enter batting or bowling) : ")
        if user_inning=="batting":
            comp_inning="bowling"
            print('user won the toss ,user has chosen batting so computer will be bowling')
            print("user will be",user_inning,"and computer will be",comp_inning)
            
        else :
            comp_inning="batting"
            print('user won the toss ,user has chosen bowling so computer will be batting')
            print("user will be",user_inning,"and computer will be",comp_inning)
print("the user is : ",user_inning)
print("the computer is : ",comp_inning)
user_score=0
comp_score=0
while True :
    if user_inning == "batting":
        user_bat=int(input('enter the value between 1 and 6 : '))
        comp_bowl=random.choice(l)
        print("the computer given value for its bowling is",comp_bowl)
        if user_bat != comp_bowl :
            user_score=user_score+user_bat   
        else:
            print("user is out and his score is",user_score)
            target=user_score+1
            print("\n","computer needs",user_score+1," runs to win")
            user_inning = "bowling"
            while user_inning == "bowling":
                user_bowl=int(input('enter the value between 1 and 6 : '))
                comp_bat=random.choice(l)
                print("the computer given value for batting is",comp_bat)
                if user_bowl != comp_bat :
                    comp_score=comp_score+comp_bat
                    if target > comp_score:
                        print("computer needs ",target-comp_score,"runs to win")
                    else:
                        print("the computer score is",comp_score)
                        print("computer won the game")
                        user_inning = "fielding"
                        break
                else:
                    if user_score > comp_score:
                        print("user won the game")
                        print("user score is ",user_score)
                        print("computer score is",comp_score)
                        user_inning = "fielding"
                        break
                    elif user_score < comp_score:
                        print("computer won the game")
                        print("user score is ",user_score)
                        print("computer score is",comp_score)
                        user_inning = "fielding"
                        break
                    else:
                        print("match is drawn")
                        print("user score is ",user_score)
                        print("computer score is",comp_score)
                    break           
    elif user_inning == "bowling":
        comp_bat=random.choice(l)
        user_bowl=int(input('enter the value between 1 and 6 : '))
        if user_bowl != comp_bat:
            comp_score=comp_score+comp_bat
            print("computer given value is : ",comp_bat)
        else:
            print("computer is out and the score is",comp_score)
            print("\n","user needs",comp_score+1," runs to win")
            target=comp_score+1
            user_inning="batting"
            while user_inning=="batting":
                comp_bowl=random.choice(l)
                user_bat=int(input('enter the value between 1 and 6 : '))
                print("the computer given value for bowling is : ",comp_bowl)
                if user_bat != comp_bowl :
                    user_score=user_score+user_bat
                    if target > user_score:
                        print("user needs ",target-user_score,"runs to win")
                    else:
                        print("the user score is",user_score)
                        print("user won the game")
                        user_inning = "fielding"
                        break
                else:
                    if user_score > comp_score:
                        print("user won the game")
                        user_inning = "fielding"
                        break
                    elif user_score < comp_score:
                        print("computer won the game")
                        user_inning = "fielding"
                        break
                    else:
                        print("match is drawn")
                        print("user score is ",user_score)
                        print("computer score is",comp_score)
                        user_inning = "fielding"
                    break     
    else:
        break
# Out:
# enter your decision between even or odd : even
# enter number between 1 to 6 for the toss : 4
# user entered :  4
# computer value between 1 and 6  is :  5
# the total value of user and computer is :  9
# computer won the toss
# computer has chosen to : bowling
#
#
# user lost the toss , computer has chosen bowling so user will be batting
# user will be batting computer will be bowling
# the user is :  batting
# the computer is :  bowling
# enter the value between 1 and 6 : 5
# the computer given value for its bowling is 6
# enter the value between 1 and 6 : 4
# the computer given value for its bowling is 2
# enter the value between 1 and 6 : 3
# the computer given value for its bowling is 4
# enter the value between 1 and 6 : 6
# the computer given value for its bowling is 1
# enter the value between 1 and 6 : 2
# the computer given value for its bowling is 2
# user is out and his score is 18
#
#  computer needs 19  runs to win
# enter the value between 1 and 6 : 4
# ...
